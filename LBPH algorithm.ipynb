# %% [markdown]
# ## Parameters: the LBPH uses 4 parameters:
# **Radius**: the radius is used to build the circular local binary pattern and represents the radius around the central pixel. It is usually set to 1.
# **Neighbors**: the number of sample points to build the circular local binary pattern. Keep in mind: the more sample points you include, the higher the computational cost. It is usually set to 8.
# **Grid X**: the number of cells in the horizontal direction. The more cells, the finer the grid, the higher the dimensionality of the resulting feature vector. It is usually set to 8.
# **Grid Y**: the number of cells in the vertical direction. The more cells, the finer the grid, the higher the dimensionality of the resulting feature vector. It is usually set to 8.

# %% [markdown]
# ## Training Dataset
# ##### What we need
# 1. **Dataset**: facial images of the people we want to recognize
# 2. **ID** (usually the name of the face) : to give you the output

# %% [markdown]
# ## Applying the LBP operation
# #### highlighting the facial characteristics.
# What we need:
# 1. **radius**
# 2. **neighbors**
# ![image-2.png](attachment:image-2.png)
# **Process of LBP**:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Extracting the Histograms
# **Grid X and Grid Y parameters**: divide the image into multiple grids
# ![image.png](attachment:image.png)
#  Supposing we have 8x8 grids, we will have 8x8x256=16.384 positions in the final histogram.

# %% [markdown]
# ## Performing the face recognition
# with trained algorithm, each histogram created is used to represent each image from the training dataset.
# To find the image that matches the input image we just need to compare two histograms and return the image with the closest histogram.
# ex)![image.png](attachment:image.png)
# The distance between two histogram is refered as ‘confidence’ measurement.
